# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruvin3103/sem5/blob/main/DMW/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# Single Variate Regression

# %%
url = "https://raw.githubusercontent.com/devzohaib/Simple-Linear-Regression/master/tvmarketing.csv"
ds = pd.read_csv(url)
print(ds)
x = ds.TV
y = ds.Sales
plt.scatter(x, y)
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("DataSet")
plt.show()

X_train,X_test,Y_train,Y_test = train_test_split(x,y,train_size=0.7,random_state=42)
X_train = X_train[:, np.newaxis]
X_test = X_test[:, np.newaxis]

lr = LinearRegression()
lr.fit(X_train,Y_train)
Y_pred = lr.predict(X_test)
plt.scatter(X_test,Y_test)
plt.xlabel("Predicated")
plt.ylabel("Actual")
plt.plot(X_test,Y_pred,linestyle="dotted",color="red")
plt.show()
print("hi")
print(f"Accuracy : {lr.score(X_test,Y_test)}")
print(f"R squared value is : {r2_score(Y_test,Y_pred)}")
print(f"means square value is : {mean_squared_error(Y_test,Y_pred)}")
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]
# <ipython-input-161-910679ab718e>:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_train = X_train[:, np.newaxis]
# <ipython-input-161-910679ab718e>:14: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_test = X_test[:, np.newaxis]
# hi
# Accuracy : 0.6714477229302764
# R squared value is : 0.6714477229302764
# means square value is : 8.970991242413614

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
reg=LinearRegression()
label_encoder = LabelEncoder()
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_csv('/content/AirQualityUCI.csv')
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10-03-2004  18:00:00     2.6         1360       150      11.9
# 1     10-03-2004  19:00:00     2.0         1292       112       9.4
# 2     10-03-2004  20:00:00     2.2         1402        88       9.0
# 3     10-03-2004  21:00:00     2.2         1376        80       9.2
# 4     10-03-2004  22:00:00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04-04-2005  10:00:00     3.1         1314      -200      13.5
# 9353  04-04-2005  11:00:00     2.4         1163      -200      11.4
# 9354  04-04-2005  12:00:00     2.4         1142      -200      12.4
# 9355  04-04-2005  13:00:00     2.1         1003      -200       9.5
# 9356  04-04-2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
df = pd.read_csv('/content/AirQualityUCI.csv')
df.dropna()
y = df['C6H6(GT)']
df.drop(['Time','Date','C6H6(GT)'], inplace=True,axis=1)
df.head(5)

X_train,X_test,Y_train,Y_test = train_test_split(df,y,train_size=0.65,random_state=42)
lr = LinearRegression()
lr.fit(X_train,Y_train)
Y_pred=lr.predict(X_test)

print("R squared value is : "+str(r2_score(Y_test,Y_pred)))
print(f"Accuracy : {lr.score(X_test,Y_test)}")
Y_pred
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10-03-2004  18:00:00     2.6         1360       150      11.9
# 1     10-03-2004  19:00:00     2.0         1292       112       9.4
# 2     10-03-2004  20:00:00     2.2         1402        88       9.0
# 3     10-03-2004  21:00:00     2.2         1376        80       9.2
# 4     10-03-2004  22:00:00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04-04-2005  10:00:00     3.1         1314      -200      13.5
# 9353  04-04-2005  11:00:00     2.4         1163      -200      11.4
# 9354  04-04-2005  12:00:00     2.4         1142      -200      12.4
# 9355  04-04-2005  13:00:00     2.1         1003      -200       9.5
# 9356  04-04-2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...
